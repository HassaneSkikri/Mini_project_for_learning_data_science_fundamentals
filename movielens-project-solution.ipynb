# %% [markdown]
# <a href="https://www.kaggle.com/code/hassaneskikri/movielens-project-solution?scriptVersionId=168046933" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# <h1 style="font-family: Trebuchet MS; padding: 12px; font-size: 30px; color: #081c15; text-align: center; line-height: 1.25;">Numpy fundamental<br><span style="color: #1b4332; font-size: 48px"><b>Data Analysis on a Movie Ratings Dataset Using NumPy</b>
#  <hr>
# <h1 style="font-family: Trebuchet MS; font-size: 14px; color: #264653; text-align: right; "><strong>Created By: Hassane Skikri</strong></h1>

# %% [markdown]
# <img src="https://cdn-images-1.medium.com/max/1000/1*Nhz7M4r_x8MuJtZ1orr0jg.gif" width="5000" height="300">

# %% [markdown]
# #### Description: This project involves using NumPy to analyze a simple dataset of movie ratings. The dataset will be a structured array containing movie titles, years, ratings, and number of reviews. You will practice array creation, manipulation, basic statistical operations, and binary operations in NumPy.

# %% [markdown]
# # <p style="background-color:#40BF80; font-family:newtimeroman;color:#FFFFFF; font-size:150% ; text-align:center; border-radius: 50px 15px;"> 🔻1️⃣ Importing libraries 🔻</p>

# %%
# !pip install numpy

import numpy as np
import pandas as pd

# %% [markdown]
# # <p style="background-color:#40BF80; font-family:newtimeroman;color:#FFFFFF; font-size:150% ; text-align:center; border-radius: 50px 15px;"> 🔻 2️⃣ Data Leading 🔻</p>

# %%
# first methode is to use genfromtxt but we may lose data 
# movies = np.genfromtxt('/kaggle/input/movielens-20m-dataset/movie.csv', delimiter=',', dtype=object, skip_header=1, invalid_raise=False)
# ratings = np.genfromtxt('/kaggle/input/movielens-20m-dataset/rating.csv', delimiter=',', dtype=object, skip_header=1, invalid_raise=False)
# to solve this problem we can use pandas as a first read the CSV and then convert it to a Numpy array

# Read in the data with pandas
movies_df = pd.read_csv('/kaggle/input/movielens-20m-dataset/movie.csv')
ratings_df = pd.read_csv('/kaggle/input/movielens-20m-dataset/rating.csv')

# Convert to NumPy arrays
movies = movies_df.to_numpy()
ratings = ratings_df.to_numpy()

# %%
movies_df.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings_df.head()
# Out:
#    userId  movieId  rating            timestamp
# 0       1        2     3.5  2005-04-02 23:53:47
# 1       1       29     3.5  2005-04-02 23:31:16
# 2       1       32     3.5  2005-04-02 23:33:39
# 3       1       47     3.5  2005-04-02 23:32:07
# 4       1       50     3.5  2005-04-02 23:29:40

# %%
ratings
# Out:
# array([[1, 2, 3.5, '2005-04-02 23:53:47'],
#        [1, 29, 3.5, '2005-04-02 23:31:16'],
#        [1, 32, 3.5, '2005-04-02 23:33:39'],
#        ...,
#        [138493, 69644, 3.0, '2009-12-07 18:10:57'],
#        [138493, 70286, 5.0, '2009-11-13 15:42:24'],
#        [138493, 71619, 2.5, '2009-10-17 20:25:36']], dtype=object)

# %% [markdown]
# # Data Exploration

# %%
print("Shape of movies:", movies.shape)
print("Shape of ratings:", ratings.shape)
# Out:
# Shape of movies: (27278, 3)
# Shape of ratings: (20000263, 4)

# %% [markdown]
# # Data Analysis with NumPy

# %%
mean_rating = np.mean(ratings[:, 2])
median_rating = np.median(ratings[:, 2])

# %% [markdown]
# # Advanced Data Manipulation

# %%
#Filter data based on criteria
filtered_ratings = ratings[ratings[:, 2] > 4]
#Sort the array based on ratings or other features:
sorted_movies = np.sort(movies, axis=0)

# %%
print(filtered_ratings.size)
filtered_ratings
# Out:
# 17733936
# array([[1, 1196, 4.5, '2005-04-02 23:32:22'],
#        [1, 1198, 4.5, '2005-04-02 23:30:24'],
#        [1, 4993, 5.0, '2005-04-02 23:31:22'],
#        ...,
#        [138493, 68954, 4.5, '2009-11-13 15:42:00'],
#        [138493, 69526, 4.5, '2009-12-03 18:31:48'],
#        [138493, 70286, 5.0, '2009-11-13 15:42:24']], dtype=object)

# %%
sorted_movies
# Out:
# array([[1, '#chicagoGirl: The Social Network Takes on a Dictator (2013)',
#         '(no genres listed)'],
#        [2, '$ (Dollars) (1971)', '(no genres listed)'],
#        [3, '$5 a Day (2008)', '(no genres listed)'],
#        ...,
#        [131258, 'Åsa-Nisse - Wälkom to Knohult (2011)', 'Western'],
#        [131260, 'Üvegtigris (2001)', 'Western'],
#        [131262, '貞子3D (2012)', 'Western']], dtype=object)

# %% [markdown]
# # Visualization

# %%
import matplotlib.pyplot as plt
plt.hist(ratings[:, 2])
plt.show()
